# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3]
y = [2,4,6]  #graph 1

# %%
x = [1,2,3]
y= [1,3,5]  #graph 2

# %%
plt.subplot(1,2,1)
plt.plot([1,2,3],[2,4,6])
plt.title("Sales")

plt.subplot(1,2,2)
plt.plot([1,2,3],[1,3,5])
plt.title("Profit")

plt.show()

# %%
## 2*2 grid

# %%
#maths 
x = [1,2,3]
y = [10,20,30]

# %%
#English
x = [1,2,3]
y = [15,25,35]

# %%
#Science 
x = [1,2,3]
y = [12,22,32]

# %%
#Hindi
x = [1,2,3]
y = [18,28,38]

# %%
plt.subplot(2,2,1)
plt.plot([1,2,3], [10,20,30])
plt.title("Maths")

plt.subplot(2,2,2)
plt.plot([1,2,3], [15,25,35])
plt.title("English")

plt.subplot(2,2,3)
plt.plot([1,2,3],[12,22,32])
plt.title("Science")

plt.subplot(2,2,4)
plt.plot([1,2,3], [18,28,38])
plt.title("Hindi")

plt.tight_layout()
plt.show()
