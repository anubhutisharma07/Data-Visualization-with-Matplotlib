# %%
import matplotlib.pyplot as plt

marks = [45, 50, 52, 55, 60, 62, 65, 70, 72, 75, 80, 85]

plt.hist(marks, bins=5)

plt.title("Student Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Number of Students")

plt.show()

# %%
import matplotlib.pyplot as plt

marks = [45, 50, 52, 55, 60, 62, 65, 70, 72, 75, 80, 85]

plt.figure(figsize=(8,5))

plt.hist(marks, bins=[40,50,60,70,80,90], edgecolor='black')

plt.title("Student Marks Distribution")
plt.xlabel("Marks Range")
plt.ylabel("Number of Students")

plt.grid(axis='y')

plt.show()

# %%
#pra quest

# %%
ages = [18, 19, 20, 21, 22, 22, 23, 24, 25, 26, 27, 28, 29, 30]

# %%
#15-20
#20-25     #age grups
#25-30
#30-35

# %%
plt.figure(figsize=(7,4))
plt.hist(ages, bins=5, edgecolor='black')

plt.title("Age Distribution")
plt.xlabel("Age Range")
plt.ylabel("Number of Members")

plt.grid(axis='y')

plt.show()

# %%
#question 2

# %%
heights = [145, 150, 152, 155, 158, 160, 162, 165, 168, 170]

# %%
plt.figure(figsize=(6,4))

plt.hist(heights, bins=[140,150,160,170], edgecolor='green')

plt.title("Height Distribution")
plt.xlabel("Height Range (cm)")
plt.ylabel("Number of Students")

plt.show()

# %%
#question 3

# %%
ages = [16, 17, 18, 18, 19, 20, 21, 22, 23, 24, 25, 26]

# %%
plt.figure(figsize=(6,4))
plt.hist(ages, bins=[15,20,25,30], edgecolor='black')

plt.title("Age Distribution")
plt.xlabel("Age Range")
plt.ylabel("Number of People")

plt.show()
